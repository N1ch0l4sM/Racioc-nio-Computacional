# %%
print("---- MENU PRINCIPAL ----\n")

print("(1) - Gerenciar Estudantes.")
print("(2) - Gerenciar Professores.")
print("(3) - Gerenciar Disciplinas.")
print("(4) - Gerenciar Turmas.")
print("(5) - Gerenciar Matrículas.")
print("(9) - Sair.")

opcao = int(input("Informe o numero a opção desejada: "))
# Out:
# ---- MENU PRINCIPAL ----
#
# (1) - Gerenciar Estudantes.
# (2) - Gerenciar Professores.
# (3) - Gerenciar Disciplinas.
# (4) - Gerenciar Turmas.
# (5) - Gerenciar Matrículas.
# (9) - Sair.

# %%
if opcao == 1:
    print("---- MENU ESTUDANTES ----\n")
    print("(1) - Incluir.")
    print("(2) - Listar.")
    print("(3) - Editar.")
    print("(4) - Excluir.")
    print("(9) - Voltar.")
    opcao = int(input("Informe o numero da ação desejada: "))
    if opcao == 1:
        print("==== Incluindo ====")
    elif opcao == 2:
        print("==== Listando ====")
    elif opcao == 3:
        print("==== Editaando ====")
    elif opcao == 4:
        print("==== Excluindo ====")
    elif opcao == 9:
        print("==== Voltando ====")
    else:
        print("Opção inválida.")
elif opcao == 2:
    print("---- MENU PROFESSORES ----\n")
    print("(1) - Incluir.")
    print("(2) - Listar.")
    print("(3) - Editar.")
    print("(4) - Excluir.")
    print("(9) - Voltar.")
    opcao = int(input("Informe o numero da ação desejada: "))
    if opcao == 1:
        print("==== Incluindo ====")
    elif opcao == 2:
        print("==== Listando ====")
    elif opcao == 3:
        print("==== Editaando ====")
    elif opcao == 4:
        print("==== Excluindo ====")
    elif opcao == 9:
        print("==== Voltando ====")
    else:
        print("Opção inválida.")
elif opcao == 3:
    print("---- MENU DISCIPLINAS ----\n")
    print("(1) - Incluir.")
    print("(2) - Listar.")
    print("(3) - Editar.")
    print("(4) - Excluir.")
    print("(9) - Voltar.")
    opcao = int(input("Informe o numero da ação desejada: "))
    if opcao == 1:
        print("==== Incluindo ====")
    elif opcao == 2:
        print("==== Listando ====")
    elif opcao == 3:
        print("==== Editaando ====")
    elif opcao == 4:
        print("==== Excluindo ====")
    elif opcao == 9:
        print("==== Voltando ====")
    else:
        print("Opção inválida.")
elif opcao == 4:
    print("---- MENU TURMAS ----\n")
    print("(1) - Incluir.")
    print("(2) - Listar.")
    print("(3) - Editar.")
    print("(4) - Excluir.")
    print("(9) - Voltar.")
    opcao = int(input("Informe o numero da ação desejada: "))
    if opcao == 1:
        print("==== Incluindo ====")
    elif opcao == 2:
        print("==== Listando ====")
    elif opcao == 3:
        print("==== Editaando ====")
    elif opcao == 4:
        print("==== Excluindo ====")
    elif opcao == 9:
        print("==== Voltando ====")
    else:
        print("Opção inválida.")
elif opcao == 5:
    print("---- MENU MATRÍCULAS ----\n")
    print("(1) - Incluir.")
    print("(2) - Listar.")
    print("(3) - Editar.")
    print("(4) - Excluir.")
    print("(9) - Voltar.")
    opcao = int(input("Informe o numero da ação desejada: "))
    if opcao == 1:
        print("==== Incluindo ====")
    elif opcao == 2:
        print("==== Listando ====")
    elif opcao == 3:
        print("==== Editaando ====")
    elif opcao == 4:
        print("==== Excluindo ====")
    elif opcao == 9:
        print("==== Voltando ====")
    else:
        print("Opção inválida.")
elif opcao == 9:
    print("==== Voltando ====")
else:
    print("Opção inválida.")
print("Fim do programa.")
# Out:
# ---- MENU Professores ----
#
# (1) - Incluir.
# (2) - Listar.
# (3) - Editar.
# (4) - Excluir.
# (9) - Voltar.
# Editar
# Fim do programa.
